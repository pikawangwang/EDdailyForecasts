# %%
import pandas as pd
import pmdarima as pm

# %%
dataL = pd.read_csv('EDvisitfileL.csv', encoding='ISO-8859-1')
dataKa = pd.read_csv('EDvisitfileKa.csv', encoding='ISO-8859-1')
dataKe = pd.read_csv('EDvisitfileKe.csv', encoding='ISO-8859-1')
dataC = pd.read_csv('EDvisitfileC.csv', encoding='ISO-8859-1')
dataT = pd.read_csv('EDvisitfileT.csv', encoding='ISO-8859-1')
dataY = pd.read_csv('EDvisitfileY.csv', encoding='ISO-8859-1')

train_end_L = 3645
train_end_Ka = 3481
train_end_Ke = 3547
train_end_C = 3510
train_end_T = 3645
train_end_Y = 2830

series_data_L = dataL['No_Linkou2']
train_series_data_L = series_data_L.iloc[:train_end_L]

series_data_Ka = dataKa['No_Kaohsiung']
train_series_data_Ka = series_data_Ka.iloc[:train_end_Ka]

series_data_Ke = dataKe['No_Keelung']
train_series_data_Ke = series_data_Ke.iloc[:train_end_Ke]

series_data_C = dataC['No_Chayi']
train_series_data_C = series_data_C.iloc[:train_end_C]

series_data_T = dataT['No_Taipei']
train_series_data_T = series_data_T.iloc[:train_end_T]

series_data_Y = dataY['No_Yunlin']
train_series_data_Y = series_data_Y.iloc[:train_end_Y]

# %%
model_L = pm.auto_arima(train_series_data_L,                      
                        seasonal=True,  # 啟用季節性
                        m='auto',       # 自動檢測季節性周期
                        stepwise=True,  # 使用階梯式搜索
                        trace=True,     # 打印過程信息
                        error_action='ignore',  # 忽略錯誤
                        suppress_warnings=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model_L = pm.auto_arima(train_series_data_L,
#       2                         seasonal=True,  # 啟用季節性
#       3                         m='auto',       # 自動檢測季節性周期
#       4                         stepwise=True,  # 使用階梯式搜索
#       5                         trace=True,     # 打印過程信息
#       6                         error_action='ignore',  # 忽略錯誤
#       7                         suppress_warnings=True)
#
# ...

# %%
model_Ka = pm.auto_arima(train_series_data_Ka, seasonal=True, trace=True,m='auto',
                    error_action='ignore', suppress_warnings=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=inf, Time=8.27 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=36064.394, Time=0.15 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=35696.065, Time=1.00 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=35766.224, Time=1.67 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=36062.402, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[7] intercept   : AIC=36017.063, Time=0.35 sec
#  ARIMA(1,1,0)(2,0,0)[7] intercept   : AIC=35517.576, Time=3.33 sec
#  ARIMA(1,1,0)(2,0,1)[7] intercept   : AIC=inf, Time=7.21 sec
#  ARIMA(1,1,0)(1,0,1)[7] intercept   : AIC=inf, Time=4.28 sec
#  ARIMA(0,1,0)(2,0,0)[7] intercept   : AIC=35622.403, Time=1.41 sec
#  ARIMA(2,1,0)(2,0,0)[7] intercept   : AIC=35474.655, Time=3.78 sec
#  ARIMA(2,1,0)(1,0,0)[7] intercept   : AIC=35649.568, Time=1.77 sec
#  ARIMA(2,1,0)(2,0,1)[7] intercept   : AIC=inf, Time=8.44 sec
#  ARIMA(2,1,0)(1,0,1)[7] intercept   : AIC=inf, Time=5.89 sec
# ...

# %%
model_Ke = pm.auto_arima(train_series_data_Ke, seasonal=True, trace=True,m=7,
                    error_action='ignore', suppress_warnings=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=inf, Time=7.49 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=36829.025, Time=0.26 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=34464.945, Time=2.23 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=35475.110, Time=1.49 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=36827.028, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[7] intercept   : AIC=36699.631, Time=0.25 sec
#  ARIMA(1,1,0)(2,0,0)[7] intercept   : AIC=33775.158, Time=5.27 sec
#  ARIMA(1,1,0)(2,0,1)[7] intercept   : AIC=inf, Time=9.60 sec
#  ARIMA(1,1,0)(1,0,1)[7] intercept   : AIC=inf, Time=3.87 sec
#  ARIMA(0,1,0)(2,0,0)[7] intercept   : AIC=34079.015, Time=1.35 sec
#  ARIMA(2,1,0)(2,0,0)[7] intercept   : AIC=33735.292, Time=5.74 sec
#  ARIMA(2,1,0)(1,0,0)[7] intercept   : AIC=34426.312, Time=2.27 sec
#  ARIMA(2,1,0)(2,0,1)[7] intercept   : AIC=inf, Time=7.78 sec
#  ARIMA(2,1,0)(1,0,1)[7] intercept   : AIC=inf, Time=5.75 sec
# ...

# %%
model_C = pm.auto_arima(train_series_data_C, seasonal=True, trace=True,m=7,
                    error_action='ignore', suppress_warnings=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=inf, Time=13.75 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=34285.816, Time=0.28 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=33648.105, Time=1.54 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=33859.076, Time=1.61 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=34283.824, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[7] intercept   : AIC=34247.997, Time=0.27 sec
#  ARIMA(1,1,0)(2,0,0)[7] intercept   : AIC=33340.037, Time=2.45 sec
#  ARIMA(1,1,0)(2,0,1)[7] intercept   : AIC=inf, Time=6.65 sec
#  ARIMA(1,1,0)(1,0,1)[7] intercept   : AIC=inf, Time=4.08 sec
#  ARIMA(0,1,0)(2,0,0)[7] intercept   : AIC=33406.221, Time=1.23 sec
#  ARIMA(2,1,0)(2,0,0)[7] intercept   : AIC=33336.697, Time=3.82 sec
#  ARIMA(2,1,0)(1,0,0)[7] intercept   : AIC=33636.298, Time=1.73 sec
#  ARIMA(2,1,0)(2,0,1)[7] intercept   : AIC=inf, Time=8.66 sec
#  ARIMA(2,1,0)(1,0,1)[7] intercept   : AIC=inf, Time=4.49 sec
# ...

# %%
model_T = pm.auto_arima(train_series_data_T, seasonal=True, trace=True,m=7,
                    error_action='ignore', suppress_warnings=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=inf, Time=6.38 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=36803.223, Time=0.15 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=34391.872, Time=1.77 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=35287.913, Time=1.74 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=36801.223, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[7] intercept   : AIC=36603.394, Time=0.32 sec
#  ARIMA(1,1,0)(2,0,0)[7] intercept   : AIC=33782.202, Time=3.61 sec
#  ARIMA(1,1,0)(2,0,1)[7] intercept   : AIC=inf, Time=6.34 sec
#  ARIMA(1,1,0)(1,0,1)[7] intercept   : AIC=inf, Time=3.81 sec
#  ARIMA(0,1,0)(2,0,0)[7] intercept   : AIC=34199.437, Time=1.34 sec
#  ARIMA(2,1,0)(2,0,0)[7] intercept   : AIC=33710.890, Time=3.66 sec
#  ARIMA(2,1,0)(1,0,0)[7] intercept   : AIC=34326.210, Time=1.89 sec
#  ARIMA(2,1,0)(2,0,1)[7] intercept   : AIC=inf, Time=9.55 sec
#  ARIMA(2,1,0)(1,0,1)[7] intercept   : AIC=inf, Time=5.16 sec
# ...

# %%
model_Y = pm.auto_arima(train_series_data_Y, seasonal=True, trace=True,m=7,
                    error_action='ignore', suppress_warnings=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=inf, Time=4.84 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=22273.405, Time=0.10 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=21508.396, Time=0.88 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=21394.124, Time=1.29 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=22271.406, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[7] intercept   : AIC=21534.473, Time=0.46 sec
#  ARIMA(0,1,1)(1,0,1)[7] intercept   : AIC=inf, Time=4.20 sec
#  ARIMA(0,1,1)(0,0,2)[7] intercept   : AIC=21237.498, Time=3.07 sec
#  ARIMA(0,1,1)(1,0,2)[7] intercept   : AIC=inf, Time=6.35 sec
#  ARIMA(0,1,0)(0,0,2)[7] intercept   : AIC=21853.270, Time=1.03 sec
#  ARIMA(1,1,1)(0,0,2)[7] intercept   : AIC=20888.641, Time=2.98 sec
#  ARIMA(1,1,1)(0,0,1)[7] intercept   : AIC=21034.436, Time=1.80 sec
#  ARIMA(1,1,1)(1,0,2)[7] intercept   : AIC=inf, Time=9.68 sec
#  ARIMA(1,1,1)(1,0,1)[7] intercept   : AIC=inf, Time=5.09 sec
# ...
